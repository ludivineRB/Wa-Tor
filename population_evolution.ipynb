# %%
#importation
import csv
import matplotlib as plt
import pandas as pd
import numpy as np

# %%
#Récupération du fichier 
data = pd.read_csv('data_WaTor.csv', sep=',')
data
# Out:
#      chronon  nb_fish  nb_shark
# 0          0      200        25
# 1          1      191        25
# 2          2      372        12
# 3          3      367        12
# 4          4      718         7
# ..       ...      ...       ...
# 829      829      964       142
# 830      830     1013       128
# 831      831     1062       121
# 832      832     1131       117
# 833      833     1122       230
#
# [834 rows x 3 columns]

# %%
data.columns
data.rename(index=str, columns={"nb_fish":"nombre de poisson", "nb_shark":"nombre de requin"}, inplace=True)
data
data["nombre total animaux"]=data["nombre de poisson"]+data["nombre de requin"]
data
# Out:
#      chronon  nombre de poisson  nombre de requin  nombre total animaux
# 0          0                200                25                   225
# 1          1                191                25                   216
# 2          2                372                12                   384
# 3          3                367                12                   379
# 4          4                718                 7                   725
# ..       ...                ...               ...                   ...
# 829      829                964               142                  1106
# 830      830               1013               128                  1141
# 831      831               1062               121                  1183
# 832      832               1131               117                  1248
# 833      833               1122               230                  1352
#
# [834 rows x 4 columns]

# %%
import matplotlib.pyplot as plt

# plot
plt.plot(data["chronon"], data["nombre de poisson"], color="lightblue")
plt.plot(data["chronon"], data["nombre de requin"], color="darkblue")

#ax.plot(x2, y2 + 2.5, 'x', markeredgewidth=2)
#ax.plot('chronon', 'nombre de poisson', linewidth=2.0)
#ax.plot(x2, y2 - 2.5, 'o-', linewidth=2)

#fig.se set(xlim=(0, 8), xticks=np.arange(1, 8),
       #ylim=(0, 100), yticks=np.arange(1, 8))

plt.show()

# %%
pip install lifelines
# Out:
# Requirement already satisfied: lifelines in ./.venv/lib/python3.12/site-packages (0.30.0)
# Requirement already satisfied: numpy>=1.14.0 in ./.venv/lib/python3.12/site-packages (from lifelines) (2.1.2)
# Requirement already satisfied: scipy>=1.7.0 in ./.venv/lib/python3.12/site-packages (from lifelines) (1.14.1)
# Requirement already satisfied: pandas>=2.1 in ./.venv/lib/python3.12/site-packages (from lifelines) (2.2.3)
# Requirement already satisfied: matplotlib>=3.0 in ./.venv/lib/python3.12/site-packages (from lifelines) (3.9.2)
# Requirement already satisfied: autograd>=1.5 in ./.venv/lib/python3.12/site-packages (from lifelines) (1.7.0)
# Requirement already satisfied: autograd-gamma>=0.3 in ./.venv/lib/python3.12/site-packages (from lifelines) (0.5.0)
# Requirement already satisfied: formulaic>=0.2.2 in ./.venv/lib/python3.12/site-packages (from lifelines) (1.0.2)
# Requirement already satisfied: interface-meta>=1.2.0 in ./.venv/lib/python3.12/site-packages (from formulaic>=0.2.2->lifelines) (1.3.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in ./.venv/lib/python3.12/site-packages (from formulaic>=0.2.2->lifelines) (4.12.2)
# Requirement already satisfied: wrapt>=1.0 in ./.venv/lib/python3.12/site-packages (from formulaic>=0.2.2->lifelines) (1.16.0)
# Requirement already satisfied: contourpy>=1.0.1 in ./.venv/lib/python3.12/site-packages (from matplotlib>=3.0->lifelines) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in ./.venv/lib/python3.12/site-packages (from matplotlib>=3.0->lifelines) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./.venv/lib/python3.12/site-packages (from matplotlib>=3.0->lifelines) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./.venv/lib/python3.12/site-packages (from matplotlib>=3.0->lifelines) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in ./.venv/lib/python3.12/site-packages (from matplotlib>=3.0->lifelines) (24.1)
# Requirement already satisfied: pillow>=8 in ./.venv/lib/python3.12/site-packages (from matplotlib>=3.0->lifelines) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in ./.venv/lib/python3.12/site-packages (from matplotlib>=3.0->lifelines) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in ./.venv/lib/python3.12/site-packages (from matplotlib>=3.0->lifelines) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.12/site-packages (from pandas>=2.1->lifelines) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in ./.venv/lib/python3.12/site-packages (from pandas>=2.1->lifelines) (2024.2)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib>=3.0->lifelines) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from lifelines import KaplanMeierFitter

# %%
kmf = KaplanMeierFitter()
kmf.fit(durations=data['chronon'], event_observed=data["nombre de poisson"])
kmf.plot_survival_function()
# Out:
# <Axes: xlabel='timeline'>

# %%
import matplotlib.pyplot as plt
import numpy as np

#plt.style.use('_mpl-gallery')

# make data
dim=(20,8)
y = data["nombre de poisson"]
z = data ['nombre de requin']
# plot
fig, ax = plt.subplots(figsize=dim)

ax.stairs(y, linewidth=1)
ax.stairs(z, linewidth=1)
ax.set(xlim=(0, len(data['chronon'])))
#ax.set(xlim=(0, data['chronon'])) #, xticks=np.arange(1, 8),
       #ylim=(0, 8), yticks=np.arange(1, 8))

plt.show()

# %%
#plt.style.use('_mpl-gallery')

# make data
dim=(20,8)
y = data["nombre de poisson"]
z = data ['nombre de requin']
# plot
fig, ax = plt.subplots(figsize=dim)

ax.stairs(y, linewidth=1)
ax.stairs(z, linewidth=1)
ax.set(xlim=(0, len(data['chronon'])))
#ax.set(xlim=(0, data['chronon'])) #, xticks=np.arange(1, 8),
       #ylim=(0, 8), yticks=np.arange(1, 8))

data = pd.read_csv('data_WaTor.csv', sep=',')
data.rename(index=str, columns={"nb_fish":"number of fish", "nb_shark":"number of sharks"}, inplace=True)
data["number of animals"]=data["number of fish"]+data["number of sharks"]
ax=plt.plot(data["chronon"], data["number of fish"], color="lightblue", label='Number of fish')
ax=plt.plot(data["chronon"], data["number of sharks"], color="darkblue", label='Number of sharks')
plt.title("Evolution des populations d'animaux")
plt.xlabel("Chronons")
plt.ylabel("Nombre d'individus")
plt.show()
# Out:
#   Cell In[54], line 17
#     data.rename(index=str, columns={"nb_fish":"number of fish", "nb_shark":"number of sharks"}, inplace=True)
#     ^
# IndentationError: unexpected indent
