# %%
#importation
import csv
import matplotlib as plt
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Récupération du fichier 
data = pd.read_csv('data_WaTor.csv', sep=',')
data
# Out:
#      chronon  nb_fish  nb_shark  average_age_fish  average_age_shark  \
# 0          0      200        25                 0                  0
# 1          1      191        25                 1                  1
# 2          2      370        12                 1                  2
# 3          3      364        12                 2                  3
# 4          4      704        12                 1                  4
# ..       ...      ...       ...               ...                ...
# 902      902     1263       139                 8                 13
# 903      903     1182       274                 9                  7
# 904      904     1097       272                 9                  8
# 905      905     1016       264                 9                  9
# 906      906      952       259                 9                 10
#
#      nb_descendants_fish  nb_descendants_shark  average_distance_fish  \
# 0                      0                     0                      0
# 1                      0                     0                      1
# 2                      0                     0                      1
# 3                      0                     0                      2
# 4                      0                     0                      2
# ..                   ...                   ...                    ...
# 902                    0                     1                      2
# 903                    0                     1                      2
# 904                    0                     1                      2
# 905                    0                     1                      2
# 906                    0                     1                      2
#
#      average_distance_shark
# 0                         0
# 1                         1
# 2                         2
# 3                         3
# 4                         4
# ..                      ...
# 902                      14
# 903                       8
# 904                       9
# 905                      10
# 906                      11
#
# [907 rows x 9 columns]

# %%
data.columns
data.rename(index=str, columns={"nb_fish":"nombre de poisson", "nb_shark":"nombre de requin"}, inplace=True)
data
data["nombre total animaux"]=data["nombre de poisson"]+data["nombre de requin"]
data
# Out:
#      chronon  nombre de poisson  nombre de requin  average_age_fish  \
# 0          0                200                25                 0
# 1          1                191                25                 1
# 2          2                370                12                 1
# 3          3                364                12                 2
# 4          4                704                12                 1
# ..       ...                ...               ...               ...
# 902      902               1263               139                 8
# 903      903               1182               274                 9
# 904      904               1097               272                 9
# 905      905               1016               264                 9
# 906      906                952               259                 9
#
#      average_age_shark  nb_descendants_fish  nb_descendants_shark  \
# 0                    0                    0                     0
# 1                    1                    0                     0
# 2                    2                    0                     0
# 3                    3                    0                     0
# 4                    4                    0                     0
# ..                 ...                  ...                   ...
# 902                 13                    0                     1
# 903                  7                    0                     1
# 904                  8                    0                     1
# 905                  9                    0                     1
# 906                 10                    0                     1
#
#      average_distance_fish  average_distance_shark  nombre total animaux
# 0                        0                       0                   225
# 1                        1                       1                   216
# 2                        1                       2                   382
# 3                        2                       3                   376
# 4                        2                       4                   716
# ..                     ...                     ...                   ...
# 902                      2                      14                  1402
# 903                      2                       8                  1456
# 904                      2                       9                  1369
# 905                      2                      10                  1280
# 906                      2                      11                  1211
#
# [907 rows x 10 columns]

# %%
plt.figure(figsize=(20,10)) 
plt.title("Average number of Sharks and Fish")
plt.plot(data["chronon"], data["nombre de poisson"], color="lightblue", label="Fish")
plt.plot(data["chronon"], data["nombre de requin"], color="darkblue", label = "Shark")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(20,10)) 
plt.title("Average Lifespan")
plt.plot(data["chronon"], data["average_age_fish"], color="lightblue", label="Fish")
plt.plot(data["chronon"], data["average_age_shark"], color="darkblue", label = "Shark")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(20,10)) 
plt.title("Average Number of Descendants")
plt.scatter(data["chronon"], data["nb_descendants_fish"], color="lightblue", label="Fish")
plt.scatter(data["chronon"], data["nb_descendants_shark"], color="darkblue", label = "Shark")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(20,10)) 
plt.title('Average Distance Traveled')
plt.plot(data["chronon"], data["average_distance_fish"], color="lightblue", label = "Fish")
plt.plot(data["chronon"], data["average_distance_shark"], color="darkblue", label = "Shark")
plt.legend()
plt.show()

# %%
data_50_200 = data.copy()
data2 = data_50_200[50:200]
plt.figure(figsize=(20,10)) 
plt.title('Average Distance Traveled vs Average Lifepan of a Shark')
plt.plot(data2["chronon"], data2["average_distance_shark"], color="lightblue", label = "Distance Traveled Shark")
plt.plot(data2["chronon"], data2["average_age_shark"], color="darkblue", label = "Lifespan of a Shark")
plt.legend()
plt.show()
